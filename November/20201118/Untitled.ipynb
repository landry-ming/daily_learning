# %% [markdown]
# 在一条环路上有 N 个加油站，其中第 i 个加油站有汽油 gas[i] 升。
#
# 你有一辆油箱容量无限的的汽车，从第 i 个加油站开往第 i+1 个加油站需要消耗汽油 cost[i] 升。你从其中的一个加油站出发，开始时油箱为空。
#
# 如果你可以绕环路行驶一周，则返回出发时加油站的编号，否则返回 -1。
#
# 说明:
#
# 如果题目有解，该答案即为唯一答案。
# 输入数组均为非空数组，且长度相同。
# 输入数组中的元素均为非负数。
# 示例 1:
#
# 输入:
# gas  = [1,2,3,4,5]
# cost = [3,4,5,1,2]
#
# 输出: 3
#
# 解释:
# 从 3 号加油站(索引为 3 处)出发，可获得 4 升汽油。此时油箱有 = 0 + 4 = 4 升汽油
# 开往 4 号加油站，此时油箱有 4 - 1 + 5 = 8 升汽油
# 开往 0 号加油站，此时油箱有 8 - 2 + 1 = 7 升汽油
# 开往 1 号加油站，此时油箱有 7 - 3 + 2 = 6 升汽油
# 开往 2 号加油站，此时油箱有 6 - 4 + 3 = 5 升汽油
# 开往 3 号加油站，你需要消耗 5 升汽油，正好足够你返回到 3 号加油站。
# 因此，3 可为起始索引。
# 示例 2:
#
# 输入:
# gas  = [2,3,4]
# cost = [3,4,3]
#
# 输出: -1
#
# 解释:
# 你不能从 0 号或 1 号加油站出发，因为没有足够的汽油可以让你行驶到下一个加油站。
# 我们从 2 号加油站出发，可以获得 4 升汽油。 此时油箱有 = 0 + 4 = 4 升汽油
# 开往 0 号加油站，此时油箱有 4 - 3 + 2 = 3 升汽油
# 开往 1 号加油站，此时油箱有 3 - 3 + 3 = 3 升汽油
# 你无法返回 2 号加油站，因为返程需要消耗 4 升汽油，但是你的油箱只有 3 升汽油。
# 因此，无论怎样，你都不可能绕环路行驶一周。

# %%
class Solution:
    def canCompleteCircuit(self, gas: List[int], cost: List[int]):
        n = len(gas)
        if n == 1:
            if gas[0] >= cost[0]:
                return 0
            else:
                return -1
        
        
        for i in range(n):
            if gas[i] > cost[i]:
                j = i+1
                rest = gas[i] - cost[i]
                while j % n  != i:
                    if rest + gas[j%n] >= cost[j%n]:
                        
                        rest += gas[j%n] - cost[j%n]
                        j += 1
                    else:
                        break
                if j % n == i:
                    return i
        return -1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7cf9f4ea72d9> in <module>
# ----> 1 class Solution:
#       2     def canCompleteCircuit(self, gas: List[int], cost: List[int]):
#       3         n = len(gas)
#       4         if n == 1:
#       5             if gas[0] >= cost[0]:
#
# <ipython-input-1-7cf9f4ea72d9> in Solution()
#       1 class Solution:
# ----> 2     def canCompleteCircuit(self, gas: List[int], cost: List[int]):
#       3         n = len(gas)
#       4         if n == 1:
#       5             if gas[0] >= cost[0]:
#
# NameError: name 'List' is not defined

# %%
class Solution:
    def canCompleteCircuit(self, gas: List[int], cost: List[int]):
        ## 如果油的总量小于花费的总量，自然无法环绕完成
        if sum(gas) < sum(cost):
            return -1
        ## 只有一个加油站的情况单独处理
        if len(gas) == 1 and gas[0] >= cost[0]:
            return 0
        ## 加油站的存油量-到下一个站的耗油量，代表到达下一个站的剩余量，小于0则到不了下一站
        new_nums = [gas[i] - cost[i] for i in range(len(gas))]
        i = 0
        while i < len(gas):
            if new_nums[i] >= 0:
                cur_gas = 0
                flag = 0
                
                for j in range(i, i+len(cost)):
                    cur_gas += new_nums[j%len(cost)]
                    
                    if cur_gas < 0:
                        pass
                    else:
                        i = max(i+1, j%len(cost))
                        flag =1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-22d12e660b2f> in <module>
# ----> 1 class Solution:
#       2     def canCompleteCircuit(self, gas: List[int], cost: List[int]):
#       3         ## 如果油的总量小于花费的总量，自然无法环绕完成
#       4         if sum(gas) < sum(cost):
#       5             return -1
#
# <ipython-input-2-22d12e660b2f> in Solution()
#       1 class Solution:
# ----> 2     def canCompleteCircuit(self, gas: List[int], cost: List[int]):
#       3         ## 如果油的总量小于花费的总量，自然无法环绕完成
#       4         if sum(gas) < sum(cost):
#       5             return -1
#
# NameError: name 'List' is not defined

# %%
class Solution:
    def canCompleteCircuit(self, gas: List[int], cost: List[int]) -> int:
        ### 如果油的总量小于花费总量，自然无法完成环绕
        if sum(gas) < sum(cost):
            return -1
        ### 只有一个加油站的情况单独处理
        if len(gas) == 1 and gas[0] >= cost[0]:
            return 0
        ### 加油站存油量 - 到下一个站的耗油量，代表到下一站时的剩余量，小于零则到不了下一站
        new_nums = [ gas[i]-cost[i] for i in range(len(cost)) ]
        ### 这里选择了while而不是for，是因为无法改变for循环中i的值
        ### 这里i的跳跃可以减少计算量
        i = 0
        while i < len(cost):
        ### 只有当某个加油站的油足够到下一个加油站才能作为起点
        ### 引入变量flag记录是否出现可行解，cur_gas记录剩余量。注意cur_gas和flag需要在每个不同i时重新变为0
        ######优化步骤1
            if new_nums[i] > 0:
                cur_gas = 0
                flag    = 0
        ### 如果可以作为起点，那么循环一周，用取余运算实现
                for j in range(i,i+len(cost)):
        ### 实时更新油剩余量
                    cur_gas = cur_gas + new_nums[j%len(cost)]
        ### 如果剩余量小于0，那么到不了下一个加油站
                    if cur_gas < 0:
        ######优化步骤2
                        if j >= len(cost):
                            return -1
        ######优化步骤3
                        else:
                            i    = max(i+1,j%len(cost))
                            flag = 1
        ### 在某处无法到下一站时直接跳出，更换起点
                        break
        ### 如果出现可行解就结束程序
                if flag == 0:
                    return i
        ### 别忘了i+1
            else:
                i = i + 1
        return -1
